# %%
# %%capture
# installing necessary dependencies and importing
# !pip install numpy pandas seaborn scipy
import numpy as np
import pandas as pd
import seaborn as sns
import itertools
from pymongo import MongoClient
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True, style='darkgrid')

# %%
# Pymongo setup
# this points to the class Atlas cluster. Feel free to change it to your own cluster.
# the dataset for this lesson can be downloaded from https://s3.us-east-2.amazonaws.com/mongodb-coursera-agg-ds/pulsars.json
course_cluster_uri = "mongodb://agg-student:agg-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin"
course_client = MongoClient(course_cluster_uri)

# %%
# grabbing the data from mongodb
pulsars =  course_client['coursera-agg']['pulsars']
df = pd.DataFrame.from_dict(list(pulsars.find({}, {"_id": 0})))

# %%
# looking at the dataframe
df.head()
# Out:
#       mean_ip  std_dev_ip  ex_kurt_ip   skew_ip  mean_dmsnr  std_dev_dmsnr  \
# 0  120.554688   45.549905    0.282924  0.419909    1.358696      13.079034
# 1  100.851562   51.743522    0.393837 -0.011241    2.841137      21.635778
# 2  117.945312   45.506577    0.325438  0.661459    2.836120      23.118350
# 3  133.257812   44.058244   -0.081060  0.115362    1.632107      12.007806
# 4  112.718750   50.301270    0.279391 -0.129011    8.281773      37.810012
#
#    ex_kurt_dmsnr  skew_dmsnr  pulsar
# 0      13.312141  212.597029       1
# 1       8.302242   71.584369       0
# 2       8.943212   82.475592       0
# 3      11.972067  195.543448       0
# 4       4.691827   21.276210       0

# %%
# another view of the data
g = sns.PairGrid(df, hue='pulsar', vars=df.drop('pulsar', axis=1).columns.values, palette='coolwarm')
g.map_offdiag(plt.scatter, alpha=0.1)
g.map_diag(plt.hist, histtype='step', linewidth=3)
g.add_legend()

# %%
# removing the class label
X = df.drop(['pulsar'], axis=1)
y = df['pulsar']

# %%
# getting a correlation matrix
corr = df.corr()

# %%
# viewing the correlation matrix
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_b2434f10_0821_11eb_917b_8c04ba99a4f9 th {
#           font-size: 7pt;
#     }    #T_b2434f10_0821_11eb_917b_8c04ba99a4f9 td {
#           padding: 0em 0em;
#     }    #T_b2434f10_0821_11eb_917b_8c04ba99a4f9 th:hover {
#           font-size: 12pt;
#     }    #T_b2434f10_0821_11eb_917b_8c04ba99a4f9 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row0_col0,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row1_col1,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row2_col2,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row3_col3,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row4_col4,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row5_col5,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row6_col6,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row7_col7,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row8_col8{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row0_col1{
#             background-color:  #96b2d5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row0_col2,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row1_col3,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row2_col0,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row3_col0,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row4_col6,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row5_col6,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row6_col5,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row7_col5,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row8_col0{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row0_col3{
#             background-color:  #db5570;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row0_col4,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row3_col7{
#             background-color:  #e8abb7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row0_col5{
#             background-color:  #e8aab6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row0_col6{
#             background-color:  #d1dbe8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row0_col7{
#             background-color:  #e2e7ee;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row0_col8,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row6_col4{
#             background-color:  #dd627b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row1_col0{
#             background-color:  #aac0dc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row1_col2{
#             background-color:  #d8405e;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row1_col4,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row2_col7{
#             background-color:  #eabcc5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row1_col5{
#             background-color:  #e9afbb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row1_col6,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row1_col7{
#             background-color:  #ebc2ca;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row1_col8,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row3_col1{
#             background-color:  #dd657d;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row2_col1{
#             background-color:  #e18093;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row2_col3,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row3_col2{
#             background-color:  #4d7fbe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row2_col4,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row5_col2{
#             background-color:  #b1c5de;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row2_col5,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row8_col5{
#             background-color:  #adc2dd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row2_col6{
#             background-color:  #e7a3b0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row2_col8,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row5_col4{
#             background-color:  #6a93c7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row3_col4,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row3_col5{
#             background-color:  #b9cae0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row3_col6,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row7_col3{
#             background-color:  #e491a1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row3_col8{
#             background-color:  #7da0cd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row4_col0{
#             background-color:  #e28396;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row4_col1,#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row7_col1{
#             background-color:  #ecc8cf;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row4_col2{
#             background-color:  #c1d0e3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row4_col3{
#             background-color:  #c3d1e4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row4_col5{
#             background-color:  #6f97c9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row4_col7{
#             background-color:  #e0768b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row4_col8{
#             background-color:  #c4d2e4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row5_col0{
#             background-color:  #e6a1af;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917b_8c04ba99a4f9row5_col1{
#             background-color:  #eed4d9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b2434f10_0821_11eb_917

# %%
# the elbow method
# we can see that we'd ideally like for 3 or 4 clusters, but we want 2 classes
# pulsar or not pulsar
Ks = range(1, 10)
km = [KMeans(n_clusters=i) for i in Ks]
score = [km[i].fit(X).score(X) for i in range(len(km))]
plt.plot(Ks, score)

# %%
# splitting into training and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
# initial kmeans, we don't expect great accuracy because we haven't scaled the data
# however, it should do decently given some of the strong correlations
clf = KMeans(n_clusters=2)
clf.fit(X_train)
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred, labels=[0, 1])

# %%
# another handy utility function to view confusion matrices in a prettier format, feel free to copy
# taken direct from the sklearn documentation and minor edits made
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    normalized = ', Normalized' if normalize else ''
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] if normalize else cm
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title("{}{}".format(title, normalized))
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cm, classes=['not pulsar', 'pulsar'])

plt.show()
cr = classification_report(y_test, y_pred, target_names=['not pulsar', 'pulsar'])
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#   not pulsar       0.90      0.83      0.87      4910
#       pulsar       0.01      0.03      0.02       460
#
#     accuracy                           0.77      5370
#    macro avg       0.46      0.43      0.44      5370
# weighted avg       0.83      0.77      0.79      5370

# %%
centers = clf.cluster_centers_
data = pd.DataFrame({'ex_kurt_dmsnr': X_test['ex_kurt_dmsnr'], 'skew_ip': X_test['skew_ip'], 'pred': y_pred, 'actual': y_test})
sns.lmplot('ex_kurt_dmsnr', 'skew_ip', data=data, hue='pred', fit_reg=False, palette='coolwarm')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
sns.lmplot('ex_kurt_dmsnr', 'skew_ip', data=data, hue='actual', fit_reg=False, palette='coolwarm')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
# Out:
# C:\Users\rasik\Anaconda3\envs\aggregation-framework\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\rasik\Anaconda3\envs\aggregation-framework\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.describe()
# Out:
#             mean_ip    std_dev_ip    ex_kurt_ip       skew_ip    mean_dmsnr  \
# count  17898.000000  17898.000000  17898.000000  17898.000000  17898.000000
# mean     111.079968     46.549532      0.477857      1.770279     12.614400
# std       25.652935      6.843189      1.064040      6.167913     29.472897
# min        5.812500     24.772042     -1.876011     -1.791886      0.213211
# 25%      100.929688     42.376018      0.027098     -0.188572      1.923077
# 50%      115.078125     46.947479      0.223240      0.198710      2.801839
# 75%      127.085938     51.023202      0.473325      0.927783      5.464256
# max      192.617188     98.778911      8.069522     68.101622    223.392141
#
#        std_dev_dmsnr  ex_kurt_dmsnr    skew_dmsnr        pulsar
# count   17898.000000   17898.000000  17898.000000  17898.000000
# mean       26.326515       8.303556    104.857709      0.091574
# std        19.470572       4.506092    106.514540      0.288432
# min         7.370432      -3.139270     -1.976976      0.000000
# 25%        14.437332       5.781506     34.960504      0.000000
# 50%        18.461316       8.433515     83.064556      0.000000
# 75%        28.428104      10.702959    139.309330      0.000000
# max       110.642211      34.539844   1191.000837      1.000000

# %%
# scaling
X = df.drop(['pulsar'], axis=1)

scaled_df = scale(X)
scaled_df = pd.DataFrame(scaled_df, columns=df.drop(['pulsar'], axis=1).columns.values)

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))
ax1.set_title('Before Scaling')
for column in X.columns.values:
    sns.kdeplot(df[column], ax=ax1)

ax2.set_title('After Min-Max Scaling')
for column in scaled_df:
    sns.kdeplot(scaled_df[column], ax=ax2)
    
plt.show()

# %%
X = scaled_df
t = pd.DataFrame(X, columns=df.drop(['pulsar'], axis=1).columns.values)
t = t.assign(pulsar=pd.Series(y))
corr = t.corr()
# viewing the correlation matrix after scaling
# proving that data was not lost
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_b74511fa_0821_11eb_9a30_8c04ba99a4f9 th {
#           font-size: 7pt;
#     }    #T_b74511fa_0821_11eb_9a30_8c04ba99a4f9 td {
#           padding: 0em 0em;
#     }    #T_b74511fa_0821_11eb_9a30_8c04ba99a4f9 th:hover {
#           font-size: 12pt;
#     }    #T_b74511fa_0821_11eb_9a30_8c04ba99a4f9 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row0_col0,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row1_col1,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row2_col2,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row3_col3,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row4_col4,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row5_col5,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row6_col6,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row7_col7,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row8_col8{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row0_col1{
#             background-color:  #96b2d5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row0_col2,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row1_col3,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row2_col0,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row3_col0,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row4_col6,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row5_col6,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row6_col5,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row7_col5,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row8_col0{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row0_col3{
#             background-color:  #db5570;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row0_col4,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row3_col7{
#             background-color:  #e8abb7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row0_col5{
#             background-color:  #e8aab6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row0_col6{
#             background-color:  #d1dbe8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row0_col7{
#             background-color:  #e2e7ee;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row0_col8,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row6_col4{
#             background-color:  #dd627b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row1_col0{
#             background-color:  #aac0dc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row1_col2{
#             background-color:  #d8405e;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row1_col4,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row2_col7{
#             background-color:  #eabcc5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row1_col5{
#             background-color:  #e9afbb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row1_col6,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row1_col7{
#             background-color:  #ebc2ca;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row1_col8,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row3_col1{
#             background-color:  #dd657d;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row2_col1{
#             background-color:  #e18093;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row2_col3,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row3_col2{
#             background-color:  #4d7fbe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row2_col4,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row5_col2{
#             background-color:  #b1c5de;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row2_col5,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row8_col5{
#             background-color:  #adc2dd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row2_col6{
#             background-color:  #e7a3b0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row2_col8,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row5_col4{
#             background-color:  #6a93c7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row3_col4,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row3_col5{
#             background-color:  #b9cae0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row3_col6,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row7_col3{
#             background-color:  #e491a1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row3_col8{
#             background-color:  #7da0cd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row4_col0{
#             background-color:  #e28396;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row4_col1,#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row7_col1{
#             background-color:  #ecc8cf;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row4_col2{
#             background-color:  #c1d0e3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row4_col3{
#             background-color:  #c3d1e4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row4_col5{
#             background-color:  #6f97c9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row4_col7{
#             background-color:  #e0768b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row4_col8{
#             background-color:  #c4d2e4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row5_col0{
#             background-color:  #e6a1af;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a30_8c04ba99a4f9row5_col1{
#             background-color:  #eed4d9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_b74511fa_0821_11eb_9a3

# %%
# elbow plot after scaling, we can see we have a sharper rise and a slightly more pronounced elbow
Ks = range(1, 10)
km = [KMeans(n_clusters=i) for i in Ks]
score = [km[i].fit(X).score(X) for i in range(len(km))]
plt.plot(Ks, score)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
df_train = pd.DataFrame(X_test, columns=df.drop(['pulsar'], axis=1).columns.values)

# %%
# kmeans on the scaled data
clf = KMeans(n_clusters=2)
clf.fit(X_train)
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cm, classes=['not pulsar', 'pulsar'])
plt.show()
cr = classification_report(y_test, y_pred, target_names=['not pulsar', 'pulsar'])
print(cr)
# plot centroids
df_train = df_train.assign(pred=pd.Series(y_pred))
df_train = df_train.assign(actual=pd.Series(y_test))
centers = clf.cluster_centers_
sns.lmplot('ex_kurt_dmsnr', 'skew_ip', data=df_train, hue='pred', fit_reg=False, palette='coolwarm')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
sns.lmplot('ex_kurt_dmsnr', 'skew_ip', data=df_train, hue='actual', fit_reg=False, palette='coolwarm')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
# Out:
#               precision    recall  f1-score   support
#
#   not pulsar       0.40      0.05      0.08      4910
#       pulsar       0.02      0.25      0.04       460
#
#     accuracy                           0.06      5370
#    macro avg       0.21      0.15      0.06      5370
# weighted avg       0.37      0.06      0.08      5370
# C:\Users\rasik\Anaconda3\envs\aggregation-framework\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\rasik\Anaconda3\envs\aggregation-framework\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pca = PCA(n_components=2)
X_pca = X
X_pca = pca.fit_transform(X_pca)

# %%
# more elbowing, much sharper rises
Ks = range(1, 10)
km = [KMeans(n_clusters=i) for i in Ks]
score = [km[i].fit(X_pca).score(X_pca) for i in range(len(km))]
plt.plot(Ks, score)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size = 0.3, random_state = 0)

# %%
clf = KMeans(n_clusters=2)
clf.fit(X_train)
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_pred, y_test)
cr = classification_report(y_pred, y_test, target_names=['not pulsar', 'pulsar'])
print(cr)
# plot confusion matrix
plt.figure()
plot_confusion_matrix(cm, classes=['not pulsar', 'pulsar'])
plt.show()
# plot centroids
centers = clf.cluster_centers_
data = pd.DataFrame({'pc1': X_test[:, 0], 'pc2': X_test[:, 1], 'pred': y_pred, 'actual': y_test})
sns.lmplot('pc1', 'pc2', data=data, hue='pred', fit_reg=False, palette='coolwarm')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
sns.lmplot('pc1', 'pc2', data=data, hue='actual', fit_reg=False, palette='coolwarm')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
# Out:
#               precision    recall  f1-score   support
#
#   not pulsar       1.00      0.97      0.98      5041
#       pulsar       0.67      0.94      0.79       329
#
#     accuracy                           0.97      5370
#    macro avg       0.84      0.96      0.88      5370
# weighted avg       0.98      0.97      0.97      5370
# C:\Users\rasik\Anaconda3\envs\aggregation-framework\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\rasik\Anaconda3\envs\aggregation-framework\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
