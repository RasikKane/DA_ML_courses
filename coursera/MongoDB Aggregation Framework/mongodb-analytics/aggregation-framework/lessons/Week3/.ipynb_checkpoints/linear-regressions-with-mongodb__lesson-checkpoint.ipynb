# %%
from pandas.io.json import json_normalize
from pymongo import MongoClient
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import numpy as np
import seaborn as sns

# %%
course_cluster_uri = "mongodb://agg-student:agg-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin"
course_client = MongoClient(course_cluster_uri)

# %%
weather_db = course_client['100YWeatherSmall']['data']

# %%
weather_filter = {
    "$match": {
        "airTemperature.value": { "$lt": 900 },
        "dewPoint.value": { "$lt": 900 },
        "pressure.value": { "$lt": 9000 },
    }
}

# %%
weather_projection = {
    "$project": {
        "_id": 0,
        "airTemperature.value": 1,
        "dewPoint.value": 1,
        "pressure.value": 1,
    }
}

# %%
sample_stage = { "$sample": { "size": 100000 } }

# %%
cursor = weather_db.aggregate([
    weather_filter,
    weather_projection,
    sample_stage
])

# %%
weather_data = list(cursor)

# %%
weather_data[0]
# Out:
# {'airTemperature': {'value': 13.0},
#  'dewPoint': {'value': 8.4},
#  'pressure': {'value': 1018.6}}

# %%
df = json_normalize(weather_data)
# Out:
# C:\Users\rasik\Anaconda3\envs\aggregation-framework\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#    airTemperature.value  dewPoint.value  pressure.value
# 0                  13.0             8.4          1018.6
# 1                  29.0            23.9          1009.0
# 2                  26.2            25.4          1012.0
# 3                  27.5            23.9          1007.4
# 4                  -4.0            -5.5          1010.0

# %%
# %matplotlib inline

# %%
sns.pairplot(df)

# %%
df_x = df.drop(['airTemperature.value'], axis=1)

# %%
df_y = df['airTemperature.value']

# %%
reg = linear_model.LinearRegression()

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.2)

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([0.97978041, 0.02960111])

# %%
reg.intercept_
# Out:
# -25.775451274502316

# %%
reg.predict(x_test)
# Out:
# array([27.28888971,  3.13063835, 27.87379785, ...,  3.15965071,
#        27.1527246 , 27.17581674])

# %%
np.mean((reg.predict(x_test) - y_test)**2)
# Out:
# 6.38931247252042
